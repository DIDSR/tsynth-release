# %% [markdown]
# ### Diffusion experiments
#
# Below presented sensitivity results for the models train on next data:
# - **tsynth** positive: 300 from **tsynth**, 100 from embed, negative: 400 from embed
# - **embed baseline** positive: 400 from embed, negative: 400 from embed
# - **subset embed baseline** positive:  100 from embed, negative: 400 from embed
# - **diffusion** positive: 300 from **unfinetined genAI**, 100 from embed, negative: 400 from embed
# - **finetuned diffusion** positive: 300 from finetuned genAI, 100 from embed, negative: 400 from embed
#
# We added only 300 synthetic images with lesions for tsynth, diffusion and finetuned diffusion experiments and the rest was taken from real (embed) data.
#
# Make sure to run: ```python download_results.py --all``` from ```code/``` directory before running this script.

# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd())) # add upper code/ directory to path 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from sklearn.metrics import auc
from utils_plot import process_results, plot_froc_by_density, plot_froc_overall
import config_global

# %%
# !mkdir -p plots/

# %%
scenario_names_add = ["tsynth","real_baseline_1", "real_baseline_2", "diffusion_simple", "diffusion"]
labels_add = {"tsynth":"tsynth","real_baseline_1":"embed baseline", "real_baseline_2":"subset embed baseline", "diffusion_simple":"diffusion ", "diffusion":"finetuned diffusion"}

root_dir_add = config_global.dir_global + '/data/results/diffusion/'

plot_froc_overall(root_dir_add, scenario_names_add, labels_add, save_path='plots/test_froc_overall_diffusion.png')
plot_froc_by_density(root_dir_add, scenario_names_add, labels_add, save_path='plots/test_froc_bd_diffusion.png')
